# %%
# !git clone https://github.com/bytedance/deer-flow.git
# %cd deer-flow
# Out:
# Cloning into 'deer-flow'...
# remote: Enumerating objects: 2712, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 2712 (delta 83), reused 76 (delta 76), pack-reused 2607 (from 3)
# Receiving objects: 100% (2712/2712), 1.63 MiB | 6.08 MiB/s, done.
# Resolving deltas: 100% (1670/1670), done.
# /content/deer-flow

# %%
# !pip install uv
# !uv sync
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 89.4 MB/s eta 0:00:00
# ...
# Using CPython 3.12.10
# Creating virtual environment at: .venv
# Resolved 117 packages in 1ms
#    Building deer-flow @ file:///content/deer-flow
#    Building deer-flow @ file:///content/deer-flow
# ⠙ Preparing packages... (0/107)
#    Building deer-flow @ file:///content/deer-flow
# ⠙ Preparing packages... (0/107)
# frozenlist ------------------------------     0 B/276.94 KiB
#    Building deer-flow @ file:///content/deer-flow
# ⠙ Preparing packages... (0/107)
# python-dateutil ------------------------------     0 B/224.50 KiB
# frozenlist ------------------------------     0 B/276.94 KiB
#    Building deer-flow @ file:///content/deer-flow
# ⠙ Preparing packages... (0/107)
# fsspec     ------------------------------     0 B/189.08 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# frozenlist ------------------------------     0 B/276.94 KiB
# ...

# %%
# !npm install -g @marp-team/marp-cli
# Out:
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: '@marp-team/marp-cli@4.1.2',
# npm WARN EBADENGINE   required: { node: '>=18' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: '@marp-team/marp-core@4.0.1',
# npm WARN EBADENGINE   required: { node: '>=18' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: '@marp-team/marpit@3.1.2',
# npm WARN EBADENGINE   required: { node: '>=18' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: 'chokidar@4.0.3',
# npm WARN EBADENGINE   required: { node: '>= 14.16.0' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# ...

# %%
# !apt-get update
# !apt-get install -y nodejs npm
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
import os
with open(".env", "w") as f:
    f.write("TAVILY_API_KEY=your_api_key\n")
    f.write("BRAVE_API_KEY=your_api_key\n")
    # Add Volcengine TTS credentials if needed

# %%
# !cp conf.yaml.example conf.yaml

# %%
with open("conf.yaml", "w") as f:
    f.write("""
    BASIC_MODEL:
      base_url: https://api.openai.com/v1
      model: gpt-4o-mini
      api_key: your_api_key
    """)

# %%
pip install inquirerpy dotenv langgraph langchain_mcp_adapters markdownify readabilipy langchain_experimental arxiv langchain_openai json_repair
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.2/151.2 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 17.6 MB/s eta 0:00:00
# ...

# %%
pip install -U duckduckgo-search
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.9 MB/s eta 0:00:00
# ...

# %%
# !python main.py "Give me a detailed profile of Indian cricketer Virat Kohli"
# Out:
# 2025-05-12 23:34:00,939 - src.workflow - INFO - Starting async workflow with user input: Give me a detailed profile of Indian cricketer Virat Kohli
# ================================ Human Message =================================
#
# Give me a detailed profile of Indian cricketer Virat Kohli
# 2025-05-12 23:34:00,941 - src.graph.nodes - INFO - Coordinator talking.
# 2025-05-12 23:34:03,010 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-12 23:34:03,031 - src.graph.nodes - INFO - background investigation node is running.
# sync [
#   {
#     "type": "page",
#     "title": "Virat Kohli - Simple English Wikipedia, the free encyclopedia",
#     "url": "https://simple.wikipedia.org/wiki/Virat_Kohli",
# ...

# %%
# Run the project in a bash-like shell
! uv run main.py "Give me a detailed profile of Indian cricketer Virat Kohli"
# Out:
# 2025-05-13 00:04:26,424 - src.workflow - INFO - Starting async workflow with user input: Give me a detailed profile of Indian cricketer Virat Kohli
# ================================ Human Message =================================
#
# Give me a detailed profile of Indian cricketer Virat Kohli
# 2025-05-13 00:04:26,429 - src.graph.nodes - INFO - Coordinator talking.
# 2025-05-13 00:04:27,522 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-13 00:04:27,547 - src.graph.nodes - INFO - background investigation node is running.
# sync [
#   {
#     "type": "page",
#     "title": "Virat Kohli - Simple English Wikipedia, the free encyclopedia",
#     "url": "https://simple.wikipedia.org/wiki/Virat_Kohli",
# ...
