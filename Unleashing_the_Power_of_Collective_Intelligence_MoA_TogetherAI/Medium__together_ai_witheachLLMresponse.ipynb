# %%
pip install together
# Out:
# Collecting together
#   Downloading together-1.2.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 838.6 kB/s eta 0:00:00
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /usr/local/lib/python3.10/dist-packages (from together) (3.9.5)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from together) (8.1.7)
# Collecting eval-type-backport<0.3.0,>=0.1.3 (from together)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /usr/local/lib/python3.10/dist-packages (from together) (3.15.4)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from together) (1.25.2)
# Collecting pillow<11.0.0,>=10.3.0 (from together)
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from together) (14.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from together) (2.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from together) (2.31.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /usr/local/lib/python3.10/dist-packages (from together) (4.66.4)
# Requirement already satisfied: typer<0.13,>=0.9 in /usr/local/lib/python3.10/dist-packages (from together) (0.12.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (4.0.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (2024.6.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13,>=0.9->together) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13,>=0.9->together) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<0.13,>=0.9->together) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<0.13,>=0.9->together) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13,>=0.9->together) (0.1.2)
# Installing collected packages: pillow, eval-type-backport, together
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.4.0 which is incompatible.
# Successfully installed eval-type-backport-0.2.0 pillow-10.4.0 together-1.2.1

# %%
import os
from together import Together
os.environ["TOGETHER_API_KEY"] = "your-api-key"

client = Together(api_key=os.environ.get("TOGETHER_API_KEY"))

response = client.chat.completions.create(
    model="meta-llama/Llama-3-8b-chat-hf",
    messages=[{"role": "user", "content": "What are some fun things to do in New York?"}],
)

print(response.choices[0].message.content)
# Out:
# The city that never sleeps! New York City is a vibrant and exciting place to visit, with endless options for entertainment, culture, and adventure. Here are some fun things to do in New York:
#
# **Iconic Landmarks:**
#
# 1. Visit the Statue of Liberty and Ellis Island: Take a ferry to Liberty Island to see the iconic statue up close and visit the Ellis Island Immigration Museum.
# 2. Walk across the Brooklyn Bridge: Enjoy stunning views of the Manhattan skyline and the East River while walking across this iconic bridge.
# 3. Explore the 9/11 Memorial & Museum: A poignant tribute to the victims of the 9/11 attacks, with two massive reflecting pools surrounded by the names of those who were killed.
#
# **Museums and Galleries:**
#
# 1. The Metropolitan Museum of Art: One of the world's largest and most famous museums, with a vast collection of art and artifacts from around the world.
# 2. The Museum of Modern Art (MoMA): A must-visit for modern art enthusiasts, with a collection that includes works by Warhol, Picasso, and Matisse.
# 3. The Guggenheim Museum: Designed by Frank Lloyd Wright, this museum features an impressive collection of modern and contemporary art.
#
# **Performing Arts:**
#
# 1. Catch a Broadway Show: New York is the hub of American theater, with dozens of iconic Broadway shows to choose from, such as Hamilton, The Lion King, and Wicked.
# 2. Visit Carnegie Hall: This legendary concert venue hosts some of the world's top musicians and orchestras.
# 3. Take in a TV Show Taping: Attend a live taping of a TV show, such as Saturday Night Live, The Tonight Show Starring Jimmy Fallon, or Good Morning America.
#
# **Food and Markets:**
#
# 1. Try a Classic New York Pizza: Visit Lombardi's, Joe's Pizza, or Patsy's Pizzeria for a slice of classic New York-style pizza.
# 2. Explore the High Line: This elevated park built on an old rail line features food vendors, gardens, and stunning city views.
# 3. Visit Smorgasburg: A weekly outdoor market in Brooklyn featuring artisanal foods, crafts, and live music.
#
# **Parks and Outdoor Spaces:**
#
# 1. Central Park: A tranquil oasis in the middle of Manhattan, with walking paths, lakes, and plenty of green space.
# 2. Prospect Park: A beautiful park in Brooklyn with a lake, walking trails, and plenty of picnic spots.
# 3. Take a Stroll along the Hudson River Greenway: Enjoy stunning views of the Hudson River and New Jersey Palisades while walking along this scenic waterfront path.
#
# **Neighborhoods to Explore:**
#
# 1. SoHo: Known for its trendy boutiques, art galleries, and cast-iron buildings.
# 2. Greenwich Village: A charming neighborhood with historic brownstones, charming streets, and plenty of restaurants and bars.
# 3. Chinatown and Little Italy: Explore the vibrant streets of Chinatown and Little Italy, with their colorful markets, street food, and cultural attractions.
#
# These are just a few of the many fun things to do in New York City. With so much to see and do, you're sure to have an unforgettable experience in the city that never sleeps!

# %%
# Mixture-of-Agents in 50 lines of code
import os
from together import Together
os.environ["TOGETHER_API_KEY"] = "your_api_key_here"

client = Together(api_key=os.environ.get("TOGETHER_API_KEY"))
import asyncio
import os
from together import AsyncTogether, Together
import os
from together import Together
os.environ["TOGETHER_API_KEY"] = "your_api_key_here"


client = Together(api_key=os.environ.get("TOGETHER_API_KEY"))
async_client = AsyncTogether(api_key=os.environ.get("TOGETHER_API_KEY"))

user_prompt = "What are some fun things to do in Hyderabad, India?"
reference_models = [
    "Qwen/Qwen2-72B-Instruct",
    "Qwen/Qwen1.5-72B-Chat",
    "mistralai/Mixtral-8x22B-Instruct-v0.1",
    "databricks/dbrx-instruct",
]
aggregator_model = "mistralai/Mixtral-8x22B-Instruct-v0.1"
aggreagator_system_prompt = """You have been provided with a set of responses from various open-source models to the latest user query. Your task is to synthesize these responses into a single, high-quality response. It is crucial to critically evaluate the information provided in these responses, recognizing that some of it may be biased or incorrect. Your response should not simply replicate the given answers but should offer a refined, accurate, and comprehensive reply to the instruction. Ensure your response is well-structured, coherent, and adheres to the highest standards of accuracy and reliability.

Responses from models:"""


async def run_llm(model):
    """Run a single LLM call with a reference model."""
    response = await async_client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=0.7,
        max_tokens=512,
    )
    print(model)
    return response.choices[0].message.content


async def main():
    results = await asyncio.gather(*[run_llm(model) for model in reference_models])

    finalStream = client.chat.completions.create(
        model=aggregator_model,
        messages=[
            {"role": "system", "content": aggreagator_system_prompt},
            {"role": "user", "content": ",".join(str(element) for element in results)},
        ],
        stream=True,
    )

    for chunk in finalStream:
        print(chunk.choices[0].delta.content or "", end="", flush=True)


# asyncio.run(main())
await main()
# Out:
# Qwen/Qwen2-72B-Instruct
# Qwen/Qwen1.5-72B-Chat
# mistralai/Mixtral-8x22B-Instruct-v0.1
# databricks/dbrx-instruct
#  Hyderabad, the capital of Telangana state, is a city rich in history, culture, and entertainment. Here are some fun things you can do while visiting:
#
# 1. **Charminar**: This iconic monument is a must-visit. It's a famous historical site and a great example of Indo-Islamic architecture.
#
# 2. **Golconda Fort**: Explore this ancient fort that was once the capital of the Qutub Shahi dynasty. It's known for its impressive acoustic effects and beautiful light and sound show in the evening.
#
# 3. **Salar Jung Museum**: This art museum houses one of the biggest one-man collections of antiques in the world. It's a great place to learn about Indian history and culture.
#
# 4. **Hussain Sagar Lake**: Enjoy a boat ride to the Buddha Statue located in the middle of the lake. The area around the lake is also a popular spot for picnics and leisurely walks.
#
# 5. **Chowmahalla Palace**: This palace complex, which once served as the official residence of the Nizams of Hyderabad, is now open to the public and offers a glimpse into the city's royal past.
#
# 6. **Ramoji Film City**: If you're a movie buff, you'll love this place. It's one of the largest integrated film cities in the world and offers a behind-the-scenes look at movie-making.
#
# 7. **Lumbini Park**: This urban park is a popular recreation spot. It has a laser show, boating, and a small amusement park.
#
# 8. **Nehru Zoological Park**: Spend a day at this large zoo, which is home to a variety of animals and birds.
#
# 9. **Laad Bazaar**: Shop for traditional Hyderabadi items like bangles, jewelry, and pearls at this bustling market.
#
# 10. **Taste the local cuisine**: Don't miss out on the famous Hyderabadi Biryani and Haleem, along with Irani Chai and Osmania Biscuits.
#
# 11. **Explore the Old City**: Wander through the narrow lanes of the old city, visit the iconic Mecca Masjid, and indulge in some street food.
#
# 12. **Visit the modern side of Hyderabad**: Known as Cyberabad, this area is home to IT parks, malls, and multiplexes. Check out the Inorbit Mall, GVK One, or the Hi-Tech City.
#
# 13. **Hyderabad Botanical Garden**: Spread across 200 acres, this garden is a haven for nature lovers and provides a peaceful escape from the city's hustle and bustle. Take a leisurely walk, birdwatch, or have a picnic.
#
# 14. **Birla Mandir**: This beautiful temple, built of white marble, is dedicated to Lord Venkateswara. Climb to the top for a panoramic view of the city.

# %%
# Suggested Changes from gemini chat ib colab



#  # Mixture-of-Agents in 50 lines of code
# import asyncio
# import os
# from together import AsyncTogether, Together

# # ... (rest of the code remains unchanged)

# # Instead of asyncio.run(main()), use await main() directly
# await main()
# Use code with caution
# By simply replacing asyncio.run(main()) with await main(), you leverage the existing event loop within the Jupyter Notebook, avoiding the conflict that caused the error.

# %%
# Mixture-of-Agents in 50 lines of code
import os
from together import Together
os.environ["TOGETHER_API_KEY"] = "your_api_key_here"

client = Together(api_key=os.environ.get("TOGETHER_API_KEY"))
import asyncio
import os
from together import AsyncTogether, Together
import os
from together import Together
os.environ["TOGETHER_API_KEY"] = "your_api_key_here"


client = Together(api_key=os.environ.get("TOGETHER_API_KEY"))
async_client = AsyncTogether(api_key=os.environ.get("TOGETHER_API_KEY"))

user_prompt = "What is Karma Yoga as per Bhagavad Gita, Vyadha Gita, Yoga Vasistham and Tripura Rahasya?"
reference_models = [
    "Qwen/Qwen2-72B-Instruct",
    "Qwen/Qwen1.5-72B-Chat",
    "mistralai/Mixtral-8x22B-Instruct-v0.1",
    "databricks/dbrx-instruct",
]
aggregator_model = "mistralai/Mixtral-8x22B-Instruct-v0.1"
aggreagator_system_prompt = """You have been provided with a set of responses from various open-source models to the latest user query. Your task is to synthesize these responses into a single, high-quality response. It is crucial to critically evaluate the information provided in these responses, recognizing that some of it may be biased or incorrect. Your response should not simply replicate the given answers but should offer a refined, accurate, and comprehensive reply to the instruction. Ensure your response is well-structured, coherent, and adheres to the highest standards of accuracy and reliability.

Responses from models:"""


async def run_llm(model):
    """Run a single LLM call with a reference model."""
    response = await async_client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=0.7,
        max_tokens=512,
    )
    print(model)
    return response.choices[0].message.content


async def main():
    results = await asyncio.gather(*[run_llm(model) for model in reference_models])

    finalStream = client.chat.completions.create(
        model=aggregator_model,
        messages=[
            {"role": "system", "content": aggreagator_system_prompt},
            {"role": "user", "content": ",".join(str(element) for element in results)},
        ],
        stream=True,
    )

    for chunk in finalStream:
        print(chunk.choices[0].delta.content or "", end="", flush=True)


# asyncio.run(main())
await main()
# Out:
# Qwen/Qwen2-72B-Instruct
# mistralai/Mixtral-8x22B-Instruct-v0.1
# Qwen/Qwen1.5-72B-Chat
# databricks/dbrx-instruct
#  Karma Yoga, as presented in various ancient Indian scriptures such as the Bhagavad Gita, Vyadha Gita, Yoga Vasistha, and Tripura Rahasya, is a path of spiritual practice that emphasizes selfless action and detachment from the fruits of one's labor. While the nuances may differ based on the philosophical context of each text, the core principles remain consistent.
#
# In the Bhagavad Gita, Lord Krishna describes Karma Yoga as the path of selfless action, where one performs their duties without attachment to the results, offering the fruits of their labor to the divine. This path of dedicated action, aligned with one's duty and performed with a pure heart, free from ego and personal desires, is also illustrated in the Vyadha Gita through the story of a hunter who achieves spiritual enlightenment.
#
# The Yoga Vasistha delves deeper into the philosophical aspects of Karma Yoga, teaching the importance of detaching oneself from the bondage of the ego and false identification with the body and mind. It advocates for performing actions with a sense of detached awareness, recognizing the impermanence of the physical world, and cultivating inner peace and wisdom.
#
# In the Tripura Rahasya, Karma Yoga is part of the practice of Jnana Yoga, or the path of knowledge. Here, Karma Yoga involves performing actions with a clear understanding of the non-dual nature of reality, acting without attachment, and recognizing the unity of the self with the universal consciousness.
#
# In summary, Karma Yoga across these texts is a path of action performed with a sense of detachment, dedication, and a clear understanding of the non-dual nature of reality. It involves performing one's duties without attachment to the results, with the ultimate goal of spiritual purification and liberation.

# %% [markdown]
# This wil capture each LLM's resposne

# %%
import os
from together import Together
os.environ["TOGETHER_API_KEY"] = "your_api_key_here"

client = Together(api_key=os.environ.get("TOGETHER_API_KEY"))
import asyncio
from together import AsyncTogether

async_client = AsyncTogether(api_key=os.environ.get("TOGETHER_API_KEY"))

user_prompt = "What is Karma Yoga as per Bhagavad Gita, Vyadha Gita, Yoga Vasistham and Tripura Rahasya?"
reference_models = [
    "Qwen/Qwen2-72B-Instruct",
    "Qwen/Qwen1.5-72B-Chat",
    "mistralai/Mixtral-8x22B-Instruct-v0.1",
    "databricks/dbrx-instruct",
]
aggregator_model = "mistralai/Mixtral-8x22B-Instruct-v0.1"
aggregator_system_prompt = """You have been provided with a set of responses from various open-source models to the latest user query. Your task is to synthesize these responses into a single, high-quality response. It is crucial to critically evaluate the information provided in these responses, recognizing that some of it may be biased or incorrect. Your response should not simply replicate the given answers but should offer a refined, accurate, and comprehensive reply to the instruction. Ensure your response is well-structured, coherent, and adheres to the highest standards of accuracy and reliability.

Responses from models:"""


async def run_llm(model):
    """Run a single LLM call with a reference model."""
    response = await async_client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=0.7,
        max_tokens=512,
    )
    print(f"Response from {model}: {response.choices[0].message.content}\n")
    return response.choices[0].message.content


async def main():
    results = await asyncio.gather(*[run_llm(model) for model in reference_models])

    finalStream = client.chat.completions.create(
        model=aggregator_model,
        messages=[
            {"role": "system", "content": aggregator_system_prompt},
            {"role": "user", "content": ",".join(str(element) for element in results)},
        ],
        stream=True,
    )

    for chunk in finalStream:
        print(chunk.choices[0].delta.content or "", end="", flush=True)


# asyncio.run(main())
await main()
# Out:
# Response from Qwen/Qwen2-72B-Instruct: Karma Yoga, often translated as the Yoga of Action, is a concept central to several Hindu scriptures, including the Bhagavad Gita, Vyadha Gita, Yoga Vasistha, and Tripura Rahasya. While the essence of Karma Yoga is common across these texts, each presents its own unique perspective and interpretation. Here's a brief overview of how Karma Yoga is understood in each of these texts:
#
# 1. **Bhagavad Gita**: The Bhagavad Gita, a 700-verse Hindu scripture that is part of the Indian epic Mahabharata, is perhaps the most well-known source for the concept of Karma Yoga. In the Gita, Krishna teaches Arjuna about the importance of performing one's duty (dharma) without attachment to the results of actions (nishkam karma). He emphasizes that one should act selflessly, without desire for personal gain, and with a sense of devotion (bhakti). Karma Yoga, as described in the Gita, is about dedicating one's actions to a higher divinity or purpose, thereby transcending the cycle of karma.
#
# 2. **Vyadha Gita**: The Vyadha Gita is a section of the Bhagavata Purana that tells the story of a hunter (vyadha) who through selfless actions and devotion to a deity, attains spiritual liberation. The story illustrates that even a person involved in traditionally 'unclean' professions can attain spiritual purity and enlightenment through the practice of Karma Yoga. The Vyadha Gita emphasizes the importance of performing one's duties with a pure heart, without attachment to the fruits of one's actions.
#
# 3. **Yoga Vasistha**: The Yoga Vasistha is a Hindu scripture that delves into various aspects of yoga, including Karma Yoga. In this text, the concept of Karma Yoga is closely tied to the understanding of the true nature of reality (Brahman) and the self (Atman). It teaches that by performing actions with a clear and pure mind, one can transcend the limitations of the ego and merge with the universal consciousness. The Yoga Vasistha emphasizes the importance of detachment, wisdom, and dispassion in the practice of Karma Yoga.
#
# 4. **Tripura Rahasya**: The Tripura Rahasya is a philosophical text that discusses the nature of the universe and the self. It presents Karma Yoga as a means to dissolve the ego and realize the non-dual nature of existence. The text encourages
#
# Response from mistralai/Mixtral-8x22B-Instruct-v0.1:  Karma Yoga is a significant concept in Hindu philosophy, especially as discussed in the Bhagavad Gita, Vyadha Gita, Yoga Vasistham, and Tripura Rahasya. It is the path of selfless action and service performed without attachment to the results, leading to spiritual growth and ultimately, self-realization.
#
# 1. Bhagavad Gita: In the Bhagavad Gita, Karma Yoga is introduced by Lord Krishna to Arjuna as a way to attain peace and self-realization. Krishna emphasizes that one should act according to one's duty (dharma) without focusing on the fruits of their labor. By performing actions selflessly and with complete devotion, an individual can transcend the cycle of birth and death and attain liberation (moksha).
#
# 2. Vyadha Gita: In the Vyadha Gita, which is a conversation between a butcher and a sage named Kausika, the concept of Karma Yoga is discussed in terms of performing one's duty sincerely and selflessly. The butcher explains that he performs his work without attachment to the results and with a pure heart, which leads to his spiritual growth. This underscores the idea that any work, when done selflessly, can be a form of worship and lead to spiritual progress.
#
# 3. Yoga Vasistham: The Yoga Vasistham is a spiritual text that discusses various concepts of yoga and self-realization. In this text, Karma Yoga is presented as the path of action, where one performs their duties without attachment and with a clear understanding of the transient nature of the world. By engaging in selfless action, an individual can overcome their ego and attain self-realization.
#
# 4. Tripura Rahasya: In the Tripura Rahasya, Karma Yoga is discussed as a means to attain self-realization through selfless action and service. The text emphasizes the importance of performing one's duties with detachment and a pure heart. By doing so, an individual can transcend their desires and attain spiritual liberation.
#
# Overall, Karma Yoga, as described in these texts, is the path of selfless action and service, performed without attachment to the results. It is a means to attain
#
# Response from Qwen/Qwen1.5-72B-Chat: Karma Yoga is a fundamental concept in several spiritual texts, including the Bhagavad Gita, Vyadha Gita, Yoga Vasistha, and Tripura Rahasya. It is a path of self-liberation through selfless action, detachment, and the cultivation of inner wisdom. Here's a brief overview of Karma Yoga as explained in each of these texts:
#
# 1. **Bhagavad Gita**: The Bhagavad Gita, one of the most renowned Hindu scriptures, is a conversation between Lord Krishna and Prince Arjuna. In this text, Karma Yoga is presented as the path of action without attachment to the results. Krishna teaches Arjuna to perform his duties without any selfish motives or expectations, focusing on the action itself rather than the fruits it may bear. This leads to inner peace, detachment, and ultimately, spiritual realization.
#
# 2. **Vyadha Gita**: Vyadha Gita is a lesser-known discourse between a hunter (Vyadha) and sage Narada. In this text, Karma Yoga is explained as the path of selfless action and detachment from the results. The hunter, through his interactions with Narada, realizes that true knowledge and liberation come from performing one's duty without being bound by the cycle of cause and effect (karma). It emphasizes the importance of acting with a pure heart and without attachment to personal desires.
#
# 3. **Yoga Vasistha**: Yoga Vasistha is a lengthy discourse between sage Vasistha and Prince Rama. In this text, Karma Yoga is seen as a means to understand the nature of the self and the world. It teaches that actions should be performed with a detached attitude and in harmony with the natural order. The text emphasizes the importance of wisdom (jnana) and self-inquiry, along with selfless action, for attaining liberation from the cycle of birth and death.
#
# 4. **Tripura Rahasya**: Tripura Rahasya is a mystical text that delves into the esoteric aspects of Hinduism, including Tantra and Advaita philosophy. In this text, Karma Yoga is mentioned as one of the three primary paths to liberation (the other two being Jnana Yoga and Bhakti Yoga). It advocates for the purification of one's actions, thoughts, and motives, ultimately leading to the realization of the non-dual nature of the self (Atman) and the universal consciousness (Brahman). Karma Yoga in Tripura Rahasya often involves the practice of rituals and ceremonies with
#
# Response from databricks/dbrx-instruct: 1. Bhagavad Gita: In the Bhagavad Gita, Karma Yoga is the yoga of selfless action. It teaches that one should perform their duties without attachment to the results. This means that one should act with a sense of detachment, without craving for rewards or being affected by the outcome. The main idea is to purify the heart and prepare oneself for the higher stages of spiritual evolution. Lord Krishna says in the Bhagavad Gita (3.19), "Therefore, without being attached to the results of activities, one should act as a matter of duty; for by working without attachment one attains the Supreme."
#
# 2. Vyadha Gita: In the Vyadha Gita, a part of the Mahabharata, Karma Yoga is explained as the path of action and duty. It emphasizes the importance of performing one's duties without attachment to the results. The story of the Vyadha (a butcher) and his conversation with the sage Kausika is used to illustrate the concept. The Vyadha explains to the sage that one should perform their duties sincerely and wholeheartedly, without being concerned about the fruits of their actions.
#
# 3. Yoga Vasistha: In the Yoga Vasistha, a classical Hindu text, Karma Yoga is described as the path of selfless action. It teaches that one should perform their duties with a sense of detachment, without being affected by the results. The text emphasizes that by performing actions without attachment, one can achieve inner peace and spiritual growth. It also explains that the real bondage is the attachment to the results of actions, and the real freedom is the detachment from the results.
#
# 4. Tripura Rahasya: In the Tripura Rahasya, a Hindu text on Advaita Vedanta, Karma Yoga is explained as the path of selfless action and service. It teaches that one should perform their duties without being attached to the results. The text emphasizes that by performing actions without attachment, one can purify their mind and prepare themselves for the higher stages of spiritual evolution. It also explains that the real bondage is the desire for the fruits of action, and the real freedom is the renunciation of the desire for the fruits of action.
#
# In summary, all these texts emphasize the importance of selfless action, performing one's duties without attachment to the results, and the importance of inner peace and spiritual growth in Karma Yoga.
#
#  Karma Yoga is a central concept in several Hindu scriptures, including the Bhagavad Gita, Vyadha Gita, Yoga Vasistha, and Tripura Rahasya. It is a path of self-liberation through selfless action, detachment, and the cultivation of inner wisdom. Here's a brief overview of Karma Yoga as explained in each of these texts:
#
# 1. Bhagavad Gita: In the Bhagavad Gita, Karma Yoga is presented as the path of action without attachment to the results. Krishna teaches Arjuna to perform his duties without any selfish motives or expectations, focusing on the action itself rather than the fruits it may bear. This leads to inner peace, detachment, and ultimately, spiritual realization.
#
# 2. Vyadha Gita: In the Vyadha Gita, Karma Yoga is explained as the path of selfless action and detachment from the results. The story of a hunter (Vyadha) and sage Narada illustrates that true knowledge and liberation come from performing one's duty without being bound by the cycle of cause and effect (karma). It emphasizes the importance of acting with a pure heart and without attachment to personal desires.
#
# 3. Yoga Vasistha: In the Yoga Vasistha, Karma Yoga is seen as a means to understand the nature of the self and the world. It teaches that actions should be performed with a detached attitude and in harmony with the natural order. The text emphasizes the importance of wisdom (jnana) and self-inquiry, along with selfless action, for attaining liberation from the cycle of birth and death.
#
# 4. Tripura Rahasya: In the Tripura Rahasya, Karma Yoga is mentioned as one of the three primary paths to liberation (the other two being Jnana Yoga and Bhakti Yoga). It advocates for the purification of one's actions, thoughts, and motives, ultimately leading to the realization of the non-dual nature of the self (Atman) and the universal consciousness (Brahman).
#
# In summary, Karma Yoga is a spiritual path that emphasizes selfless action, detachment from the results, and the cultivation of inner wisdom. It is a means to attain inner peace, self-realization, and liberation from the cycle of birth and death. Each of the aforementioned texts offers a unique perspective on Karma Yoga, highlighting its importance in the pursuit of spiritual growth and enlightenment.
